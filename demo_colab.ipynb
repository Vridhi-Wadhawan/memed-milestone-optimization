# %% [markdown]
# # Milestone ladder demo
# Thin wrapper around the repo. All logic lives in `src/`. Set `REPO_URL` below first.

# %%
REPO_URL = "https://github.com/YOUR_USERNAME/memed-milestone-optimization"  # change this
# !git clone $REPO_URL repo
# %cd repo
# !pip install -q -r requirements.txt

# %%
# !python run.py --category finance --platform youtube --tier mid --budget 400000 --creators 60

# %%
# Backtest results were generated by src/backtest.py (about 2.5 minutes to rerun)
from IPython.display import Markdown
Markdown(open("outputs/backtest_report.md", encoding="utf-8").read())
